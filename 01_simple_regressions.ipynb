# %% [markdown]
# # Lecture 1
#
# ## Introduction to [Regressions](#regression)
#  - binary means (close vs far)
#  - pre-specified categories with means
#  - non-parametric regression (lowess)
#  - simple linear regression (OLS)
#  - analysis of the results
#  - Log models
#
# #### Case-study:
# - Hotels Vienna
#
# #### Dataset:
# - hotels-vienna
#
#
# ___

# %% [markdown]
# ## Introduction to Regression<a class = 'anchor' id = 'regression'></a>

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (22.3)
# Collecting pip
#   Using cached pip-24.3.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3
#     Uninstalling pip-22.3:
#       Successfully uninstalled pip-22.3
# Successfully installed pip-24.3.1

# %%
# !pip --version
# Out:
# pip 24.3.1 from C:\Users\Пользователь\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip (python 3.11)

# %%
# !pip install patchworklib
# Out:
# Requirement already satisfied: patchworklib in c:\users\пользователь\appdata\roaming\python\python311\site-packages (0.6.5)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from patchworklib) (3.9.2)
# Requirement already satisfied: pandas>=0.24 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from patchworklib) (2.2.3)
# Requirement already satisfied: numpy<1.27,>=1.16 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from patchworklib) (1.26.4)
# Requirement already satisfied: dill in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from patchworklib) (0.3.9)
# Requirement already satisfied: seaborn in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from patchworklib) (0.13.2)
# Requirement already satisfied: plotnine<=0.13.6 in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from patchworklib) (0.13.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.24->patchworklib) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.24->patchworklib) (2024.2)
# Requirement already satisfied: mizani~=0.11.0 in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from plotnine<=0.13.6->patchworklib) (0.11.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from plotnine<=0.13.6->patchworklib) (1.14.1)
# Requirement already satisfied: statsmodels>=0.14.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from plotnine<=0.13.6->patchworklib) (0.14.4)
# Requirement already satisfied: six>=1.5 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->patchworklib) (1.16.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.14.0->plotnine<=0.13.6->patchworklib) (0.5.6)

# %%
# !pip install patchworklib --user
# Out:
# Requirement already satisfied: patchworklib in c:\users\пользователь\appdata\roaming\python\python311\site-packages (0.6.5)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from patchworklib) (3.9.2)
# Requirement already satisfied: pandas>=0.24 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from patchworklib) (2.2.3)
# Requirement already satisfied: numpy<1.27,>=1.16 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from patchworklib) (1.26.4)
# Requirement already satisfied: dill in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from patchworklib) (0.3.9)
# Requirement already satisfied: seaborn in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from patchworklib) (0.13.2)
# Requirement already satisfied: plotnine<=0.13.6 in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from patchworklib) (0.13.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.4->patchworklib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.24->patchworklib) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.24->patchworklib) (2024.2)
# Requirement already satisfied: mizani~=0.11.0 in c:\users\пользователь\appdata\roaming\python\python311\site-packages (from plotnine<=0.13.6->patchworklib) (0.11.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from plotnine<=0.13.6->patchworklib) (1.14.1)
# Requirement already satisfied: statsmodels>=0.14.0 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from plotnine<=0.13.6->patchworklib) (0.14.4)
# Requirement already satisfied: six>=1.5 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->patchworklib) (1.16.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\пользователь\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.14.0->plotnine<=0.13.6->patchworklib) (0.5.6)

# %%
import warnings

import numpy as np
import pandas as pd
import patchworklib as pw
from plotnine import *
from skimpy import skim

# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# Import packages

# %% [markdown]
# From OSF import hotel-vienna data

# %%
hotels = pd.read_csv("hotels-vienna.csv")

# %%
hotels
# Out:
#      country city_actual  rating_count center1label center2label  \
# 0    Austria      Vienna          36.0  City centre    Donauturm
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 423  Austria      Vienna           2.0  City centre    Donauturm
# 424  Austria      Vienna         145.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
# 427  Austria      Vienna          80.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...      offer_cat  year  \
# 0     17. Hernals     81  Vienna    4.0       4.5  ...   15-50% offer  2017
# 1     17. Hernals     81  Vienna    4.0       3.5  ...    1-15% offer  2017
# 2      Alsergrund     85  Vienna    4.0       3.5  ...   15-50% offer  2017
# 3      Alsergrund     83  Vienna    3.0       4.0  ...   15-50% offer  2017
# 4      Alsergrund     82  Vienna    4.0       3.5  ...   15-50% offer  2017
# ..            ...    ...     ...    ...       ...  ...            ...   ...
# 423        Wieden    109  Vienna    3.0       3.0  ...  50%-75% offer  2017
# 424        Wieden    185  Vienna    5.0       4.0  ...   15-50% offer  2017
# 425        Wieden    100  Vienna    4.0       4.5  ...    0% no offer  2017
# 426        Wieden     58  Vienna    3.0       3.0  ...   15-50% offer  2017
# 427        Wieden    110  Vienna    3.5       NaN  ...    1-15% offer  2017
#
#      month  weekend holiday  distance  distance_alter  accommodation_type  \
# 0       11        0       0       2.7             4.4           Apartment
# 1       11        0       0       1.7             3.8               Hotel
# 2       11        0       0       1.4             2.5               Hotel
# 3       11        0       0       1.7             2.5               Hotel
# 4       11        0       0       1.2             2.8               Hotel
# ..     ...      ...     ...       ...             ...                 ...
# 423     11        0       0       1.5             3.8           Apartment
# 424     11        0       0       0.8             3.6               Hotel
# 425     11        0       0       1.0             3.7               Hotel
# 426     11        0       0       1.4             4.1               Hotel
# 427     11        0       0       0.7             3.5           Apartment
#
#      nnights  rating
# 0          1     4.4
# 1          1     3.9
# 2          1     3.7
# 3          1     4.0
# 4          1     3.9
# ..       ...     ...
# 423        1     5.0
# 424        1     4.3
# 425        1     4.4
# 426        1     3.2
# 427        1     4.0
#
# [428 rows x 24 columns]

# %% [markdown]
# Apply filters:  3-4 stars, Vienna actual, without  extreme prices

# %%
hotels = (
    hotels.loc[lambda x: x["accommodation_type"] == "Hotel"]
    .loc[lambda x: x["city_actual"] == "Vienna"]
    .loc[lambda x: x["stars"] >= 3]
    .loc[lambda x: x["stars"] <= 4]
    .loc[lambda x: x["stars"].notnull()]
    .loc[lambda x: x["price"] <= 600]
)

# %%
hotels
# Out:
#      country city_actual  rating_count center1label center2label  \
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# 6    Austria      Vienna          57.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 420  Austria      Vienna          77.0  City centre    Donauturm
# 421  Austria      Vienna         572.0  City centre    Donauturm
# 422  Austria      Vienna          53.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...     offer_cat  year  \
# 1     17. Hernals     81  Vienna    4.0       3.5  ...   1-15% offer  2017
# 2      Alsergrund     85  Vienna    4.0       3.5  ...  15-50% offer  2017
# 3      Alsergrund     83  Vienna    3.0       4.0  ...  15-50% offer  2017
# 4      Alsergrund     82  Vienna    4.0       3.5  ...  15-50% offer  2017
# 6      Alsergrund    103  Vienna    4.0       3.5  ...   0% no offer  2017
# ..            ...    ...     ...    ...       ...  ...           ...   ...
# 420        Wieden    100  Vienna    3.0       4.0  ...   1-15% offer  2017
# 421        Wieden     95  Vienna    4.0       4.0  ...   1-15% offer  2017
# 422        Wieden     73  Vienna    3.0       3.0  ...   1-15% offer  2017
# 425        Wieden    100  Vienna    4.0       4.5  ...   0% no offer  2017
# 426        Wieden     58  Vienna    3.0       3.0  ...  15-50% offer  2017
#
#      month  weekend holiday  distance  distance_alter  accommodation_type  \
# 1       11        0       0       1.7             3.8               Hotel
# 2       11        0       0       1.4             2.5               Hotel
# 3       11        0       0       1.7             2.5               Hotel
# 4       11        0       0       1.2             2.8               Hotel
# 6       11        0       0       0.9             2.4               Hotel
# ..     ...      ...     ...       ...             ...                 ...
# 420     11        0       0       1.2             3.7               Hotel
# 421     11        0       0       1.5             3.9               Hotel
# 422     11        0       0       1.5             4.0               Hotel
# 425     11        0       0       1.0             3.7               Hotel
# 426     11        0       0       1.4             4.1               Hotel
#
#      nnights  rating
# 1          1     3.9
# 2          1     3.7
# 3          1     4.0
# 4          1     3.9
# 6          1     3.9
# ..       ...     ...
# 420        1     4.0
# 421        1     4.1
# 422        1     3.4
# 425        1     4.4
# 426        1     3.2
#
# [207 rows x 24 columns]

# %% [markdown]
# Summary statistics on price and distance

# %%
hotels.filter(["price", "distance"]).describe(percentiles=[0.25, 0.5, 0.75, 0.95]).T
# Out:
#           count        mean        std   min   25%    50%    75%    95%    max
# price     207.0  109.975845  42.221381  50.0  82.0  100.0  129.5  183.4  383.0
# distance  207.0    1.529952   1.161507   0.0   0.8    1.3    1.9    3.9    6.6

# %%
skim(hotels.filter(["price","distance"]))
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 207    │ │ int32       │ 1     │                                                          │
# │ │ Number of columns │ 2      │ │ float64     │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name      ┃ NA   ┃ NA %    ┃ mean    ┃ sd       ┃ p0   ┃ p25   ┃ p50   ┃ p75     ┃ p100   ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━┩  │
# │ │ price            │    0 │       0 │     110 │    42.22 │   50 │    82 │   100 │   129.5 │    383 │   ▇▅▁   │  │
# │ │ distance         │    0 │       0 │    1.53 │    1.162 │    0 │   0.8 │   1.3 │     1.9 │    6.6 │  ▇▇▁▂   │  │
# │ └──────────────────┴──────┴─────────┴─────────┴──────────┴──────┴───────┴───────┴─────────┴────────┴─────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# Graphical investigation: \
# create a base scatter-plot between price and distance

# %%
p1 = (
    ggplot(data=hotels)
    + geom_point(aes(x="distance", y="price"), color="red", size=2, alpha=0.5)
    + expand_limits(x=0.01, y=0.01)
    + scale_y_continuous(
        expand=(0.05, 0.05), limits=(0, 400), breaks=np.arange(0, 401, 20)
    )
    + labs(x="Distance to city center (miles)", y="Price (US dollars)")
    + theme_bw()
)
p1

# %% [markdown]
# ### Binary Variable

# %% [markdown]
# Close vs Far away hotels with a binary variable:
#  - if further away from 2 miles, consider as 'far', otherwise 'close'

# %%
hotels["dist2"] = np.where(hotels["distance"] >= 2, "Far", "Close")
hotels["Eprice_cat2"] = hotels.groupby("dist2")["price"].transform("mean")

# %%
hotels
# Out:
#      country city_actual  rating_count center1label center2label  \
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# 6    Austria      Vienna          57.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 420  Austria      Vienna          77.0  City centre    Donauturm
# 421  Austria      Vienna         572.0  City centre    Donauturm
# 422  Austria      Vienna          53.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...  month  weekend  \
# 1     17. Hernals     81  Vienna    4.0       3.5  ...     11        0
# 2      Alsergrund     85  Vienna    4.0       3.5  ...     11        0
# 3      Alsergrund     83  Vienna    3.0       4.0  ...     11        0
# 4      Alsergrund     82  Vienna    4.0       3.5  ...     11        0
# 6      Alsergrund    103  Vienna    4.0       3.5  ...     11        0
# ..            ...    ...     ...    ...       ...  ...    ...      ...
# 420        Wieden    100  Vienna    3.0       4.0  ...     11        0
# 421        Wieden     95  Vienna    4.0       4.0  ...     11        0
# 422        Wieden     73  Vienna    3.0       3.0  ...     11        0
# 425        Wieden    100  Vienna    4.0       4.5  ...     11        0
# 426        Wieden     58  Vienna    3.0       3.0  ...     11        0
#
#      holiday  distance distance_alter  accommodation_type  nnights  rating  \
# 1          0       1.7            3.8               Hotel        1     3.9
# 2          0       1.4            2.5               Hotel        1     3.7
# 3          0       1.7            2.5               Hotel        1     4.0
# 4          0       1.2            2.8               Hotel        1     3.9
# 6          0       0.9            2.4               Hotel        1     3.9
# ..       ...       ...            ...                 ...      ...     ...
# 420        0       1.2            3.7               Hotel        1     4.0
# 421        0       1.5            3.9               Hotel        1     4.1
# 422        0       1.5            4.0               Hotel        1     3.4
# 425        0       1.0            3.7               Hotel        1     4.4
# 426        0       1.4            4.1               Hotel        1     3.2
#
#      dist2  Eprice_cat2
# 1    Close   116.426752
# 2    Close   116.426752
# 3    Close   116.426752
# 4    Close   116.426752
# 6    Close   116.426752
# ..     ...          ...
# 420  Close   116.426752
# 421  Close   116.426752
# 422  Close   116.426752
# 425  Close   116.426752
# 426  Close   116.426752
#
# [207 rows x 26 columns]

# %% [markdown]
# Check the descriptives for the two categories:

# %%
(
    hotels.melt(id_vars="dist2", value_vars=["distance", "price"])
    .groupby(["dist2", "variable"])
    .agg(["mean", "std", "min", "max", "count"])
    .round(2)
)
# Out:
#                  value
#                   mean    std   min    max count
# dist2 variable
# Close distance    0.99   0.54   0.0    1.9   157
#       price     116.43  43.10  54.0  383.0   157
# Far   distance    3.21   0.97   2.0    6.6    50
#       price      89.72  32.09  50.0  208.0    50

# %% [markdown]
# Plot the two categories

# %%
(
    ggplot(data=hotels)
    + geom_point(
        aes(x="dist2", y="Eprice_cat2"), size=5, alpha=0.4, fill="red", na_rm=True
    )
    + geom_text(
        aes(x="dist2", y="Eprice_cat2 + 16", label="round(Eprice_cat2, 0)"),
        color="black",
        size=10,
    )
    + scale_y_continuous(
        expand=(0.01, 0.01), limits=(0, 400), breaks=np.arange(0, 401, 50)
    )
    + expand_limits(y=0.01)
    + scale_x_discrete()
    + labs(x="Distance to city center (categories)", y="Average price (US dollars)")
    + theme_bw()
)

# %% [markdown]
# ###  Pre-specified Categories With Means (4 Distance Categories)

# %% [markdown]
# Below 1, between 1 and 2, between 2 and 3 and above 3 -> x value will be the midpoint

# %%
hotels["dist4"] = (
    0.5
    + np.where(hotels["distance"] >= 1, 1, 0)
    + np.where(hotels["distance"] >= 2, 1, 0)
    + np.where(hotels["distance"] >= 3, 2.5, 0)
)

# %% [markdown]
# Add mean values for price given each group

# %%
hotels["Eprice_cat4"] = hotels.groupby("dist4")["price"].transform("mean")

# %%
(
    hotels.melt(id_vars="dist4", value_vars=["distance", "price"])
    .groupby(["dist4", "variable"])
    .agg(["mean", "std", "min", "max", "count"])
    .round(2)
)
# Out:
#                  value
#                   mean    std   min    max count
# dist4 variable
# 0.5   distance    0.55   0.28   0.0    0.9    81
#       price     132.91  38.54  68.0  242.0    81
# 1.5   distance    1.46   0.29   1.0    1.9    76
#       price      98.86  40.89  54.0  383.0    76
# 2.5   distance    2.35   0.32   2.0    2.9    22
#       price      97.55  40.39  54.0  208.0    22
# 5.0   distance    3.88   0.76   3.0    6.6    28
#       price      83.57  22.60  50.0  156.0    28

# %% [markdown]
# Make a graph for each segment

# %%
(
    ggplot(data=hotels)
    + geom_point(
        aes(x="dist4", y="Eprice_cat4"), size=2.5, fill="red", alpha=0.4, na_rm=True
    )
    + geom_text(
        aes(x="dist4", y="Eprice_cat4 + 15", label="round(Eprice_cat4)"),
        color="black",
        size=10,
    )
    + expand_limits(x=0.01, y=0.01)
    + coord_cartesian(xlim=(0, 7), ylim=(0, 400))
    + scale_y_continuous(
        expand=(0.01, 0.01), limits=(0, 400), breaks=np.arange(0, 401, 50)
    )
    + scale_x_continuous(
        expand=(0.01, 0.01), limits=(0, 7), breaks=[0, 1, 2, 3, 4, 5, 6, 7]
    )
    + labs(x="Distance to city center (miles)", y="Price (US dollars)")
    + theme_bw()
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# What actually is happening is a: \
# scatterplot with step function (we use 1km bits for simplicity using 4 bits for 3-7km)

# %%
hotels["dist4_s"] = (
    np.where(hotels["distance"] >= 1, 1, 0)
    + np.where(hotels["distance"] >= 2, 1, 0)
    + np.where(hotels["distance"] >= 3, 1, 0)
    + np.where(hotels["distance"] >= 4, 1, 0)
    + np.where(hotels["distance"] >= 5, 1, 0)
    + np.where(hotels["distance"] >= 6, 1, 0)
)

hotels["xend"] = hotels["dist4_s"] + 1
hotels["yend"] = hotels["Eprice_cat4"]

# %%
p1 + geom_segment(
    aes(x="dist4_s", y="yend", xend="xend", yend="yend"),
    color="blue",
    size=0.7,
    na_rm=True,
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# ###  Lowess Non-parametric Regression

# %%
p1 + geom_smooth(aes(x="distance", y="price"), color="blue", method="loess", se=False)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# - Advantage: \
#    smooth curve which represent the pattern of association pretty flexibly!
# -  Disadvantage: \
#    no measurable properties: it smooth over the observations with an 'optimal' bandwidth.

# %% [markdown]
# **NOTE:** This codechunk results in error for Windows users. See: https://github.com/has2k1/scikit-misc/issues/12

# %% [markdown]
# ### Simple Linear Regression -- parameters

# %% [markdown]
# #### Random 4 observation

# %%
rnd_hotels = hotels.sample(4,random_state=123)[["hotel_id","price","distance"]]
rnd_hotels
# Out:
#      hotel_id  price  distance
# 378     22348     77       3.7
# 191     22125    104       0.7
# 298     22250    184       1.0
# 379     22349    102       5.3

# %%
avg_price = np.mean(rnd_hotels[["price"]])
avg_price
# Out:
# 116.75

# %%
avg_dist = np.mean(rnd_hotels[["distance"]])
avg_dist
# Out:
# 2.675

# %%
# Compute variance-covariance
var_cov = np.cov(rnd_hotels["distance"],rnd_hotels["price"])
var_cov
# Out:
# array([[   4.8825    ,  -55.64166667],
#        [ -55.64166667, 2160.91666667]])

# %%
beta = var_cov[0][1]/var_cov[0][0]
beta
# Out:
# -11.396142686465268

# %%
alpha = avg_price - beta*avg_dist
alpha
# Out:
# 147.23468168629458

# %%
p2 = (
    ggplot(data=rnd_hotels)
    + geom_point(aes(x="distance", y="price"), color="red", size=2, alpha=0.5)
    + expand_limits(x=0.01, y=0.01)
    + scale_x_continuous(expand=(0.01, 0.01), limits=(0, 7), breaks=range(0, 8))
    + scale_y_continuous(
        expand=(0.01, 0.01), limits=(0, 400), breaks=np.arange(0, 401, 50)
    )
    + labs(x="Distance to city center (miles)", y="Price (US dollars)")
    + theme_bw()
)
p2 + geom_smooth(
    aes(x="distance", y="price"), method="lm", color="blue", formula="y~x", se=False
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# How to quantify linear regression: \
# Remember: $y = \alpha + \beta * x + \epsilon$
#
# In Python, the [statsmodels](https://www.statsmodels.org/stable/index.html) package is usually used to estimate regressions

# %%
import statsmodels.formula.api as smf
from mizani.formatters import percent_format

# %% [markdown]
# We use the statsmodels formula api, where you can give the equations as a string.
# To replicate what we have done we can use the simple following commands:

# %%
rnd_reg = smf.ols("price ~ distance", data=rnd_hotels).fit()
print(rnd_reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                 -0.060
# Method:                 Least Squares   F-statistic:                    0.8306
# Date:                Sat, 09 Nov 2024   Prob (F-statistic):              0.458
# Time:                        18:54:42   Log-Likelihood:                -19.762
# No. Observations:                   4   AIC:                             43.52
# Df Residuals:                       2   BIC:                             42.30
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    147.2347     41.126      3.580      0.070     -29.718     324.187
# distance     -11.3961     12.504     -0.911      0.458     -65.198      42.405
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.768
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.468
# Skew:                           0.318   Prob(JB):                        0.791
# Kurtosis:                       1.449   Cond. No.                         6.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Пользователь\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.

# %% [markdown]
# #### All observations

# %% [markdown]
# Now, do the same analysis but with all observations!

# %%
p1 + geom_smooth(
    aes(x="distance", y="price"), method="lm", color="blue", formula="y~x", se=False
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
#  Simple model, with homoskedastic SE

# %%
simple_reg = smf.ols("price ~ distance", data=hotels).fit()
print(simple_reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     38.20
# Date:                Mon, 04 Nov 2024   Prob (F-statistic):           3.39e-09
# Time:                        12:45:00   Log-Likelihood:                -1050.3
# No. Observations:                 207   AIC:                             2105.
# Df Residuals:                     205   BIC:                             2111.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    132.0170      4.474     29.511      0.000     123.197     140.837
# distance     -14.4064      2.331     -6.181      0.000     -19.002      -9.811
# ==============================================================================
# Omnibus:                      141.994   Durbin-Watson:                   1.479
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1560.025
# Skew:                           2.497   Prob(JB):                         0.00
# Kurtosis:                      15.488   Cond. No.                         3.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Its wasy to compare two regression output tables using the stargazer package

# %%
from stargazer.stargazer import Stargazer

# %%
table = Stargazer([rnd_reg, simple_reg])
table.rename_covariates({"Intercept": "Constant"})
table.custom_columns(["Random 4 obs.", "ALL obs."], [1, 1])
table
# Out:
# <table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable: price</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Random 4 obs.</td><td colspan="1">ALL obs.</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr>
# <tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Constant</td><td>147.235<sup>*</sup></td><td>132.017<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(41.126)</td><td>(4.474)</td></tr>
# <tr><td style="text-align:left">distance</td><td>-11.396<sup></sup></td><td>-14.406<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(12.504)</td><td>(2.331)</td></tr>
#
# <td colspan="3" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>4</td><td>207</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.293</td><td>0.157</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.060</td><td>0.153</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>47.856 (df=2)</td><td>38.858 (df=205)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.831<sup></sup> (df=1; 2)</td><td>38.199<sup>***</sup> (df=1; 205)</td></tr>
# <tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="2" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %% [markdown]
# ## Analysis of the Linear Regression model
#    - price prediction of a model
#    - errors of predictions

# %% [markdown]
# ### Random 4 observations -- R2

# %%
# Predicted values
rnd_hotels["y_pred"] = rnd_reg.predict()
# Errors
rnd_hotels["err"] = rnd_hotels["price"] - rnd_hotels["y_pred"]

# %% [markdown]
# To calculate R2 we need the variance of the outcome (price) and its predicted values

# %%
print(np.cov(rnd_hotels['price']))
print(np.cov(rnd_hotels['y_pred']))
# Out:
# 2160.9166666666665
# 634.10037264607

# %% [markdown]
# Now, R2 is nothing but the ratio for the variance of the predicted and actual outcomes

# %%
np.cov(rnd_hotels['y_pred'])/np.cov(rnd_hotels['price'])
# Out:
# 0.2934404562783094

# %% [markdown]
# ### All observations -- residuals
#
# It is easy to save the predicted values and residuals

# %%
# Alternative ways to get the predicted values and error terms
hotels["predprice"] = simple_reg.fittedvalues
hotels["e"] = simple_reg.resid

# %% [markdown]
# Get the hotel, which is the most underpriced

# %%
hotels.sort_values(by="e").head(1)
# Out:
#      country city_actual  rating_count center1label center2label  \
# 153  Austria      Vienna          63.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...  rating  dist2  \
# 153    Josefstadt     54  Vienna    3.0       3.0  ...     3.2  Close
#
#      Eprice_cat2  dist4 Eprice_cat4  dist4_s  xend       yend  predprice  \
# 153   116.426752    1.5   98.855263        1     2  98.855263  116.16991
#
#             e
# 153 -62.16991
#
# [1 rows x 33 columns]

# %% [markdown]
# probably we are only interested in hotel_id, distance, price, prediction and error values:

# %%
hotels.sort_values(by="e").head(1).filter(["hotel_id","distance","price","predprice","e"])
# Out:
#      hotel_id  distance  price  predprice         e
# 153     22080       1.1     54  116.16991 -62.16991

# %% [markdown]
#  Interpret the result!

# %% [markdown]
# We can get the 5 most overpriced five hotels

# %%
hotels.sort_values(by="e", ascending=False).head(5).filter(
    ["hotel_id", "distance", "price", "predprice", "e"]
)
# Out:
#      hotel_id  distance  price   predprice           e
# 247     22193       1.9    383  104.644774  278.355226
# 26      21930       2.9    208   90.238353  117.761647
# 128     22050       0.0    242  132.016973  109.983027
# 110     22031       0.1    231  130.576331  100.423669
# 129     22051       0.5    223  124.813762   98.186238

# %% [markdown]
# Checking the histogram of residuals:\
# we can better understand about how well we can predict the prices\
# notes:
#    - we picked previously the smallest and 5 largest values from here
#    - on average we will have 0 error, as this is a property of the OLS estimator

# %%
(
    ggplot(hotels, aes(x="e"))
    + geom_histogram(
        aes(y=after_stat("count / np.sum(count)")),
        binwidth=20,
        fill="blue",
        color="white",
        size=0.2,
        alpha=0.8,
        na_rm=True,
    )
    + labs(x="Residuals", y="Percent")
    + scale_x_continuous(limits=(-100, 300), breaks=np.arange(-100, 301, 100))
    + scale_y_continuous(
        expand=(0.0, 0.0),
        limits=(0, 0.31),
        breaks=np.arange(0, 0.31, 0.05),
        labels=percent_format(),
    )
    + theme_bw()
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# We can make a pretty graph with the bottom and top 5 deals:

# %% [markdown]
# Create a factor variable with 4 possible values

# %%
hotels["reg1_res"] = np.where(hotels["e"] >= 0, "overpriced", "underpriced")

hotels["reg1_res"] = np.where(
    hotels["hotel_id"].isin(
        hotels.sort_values(by="e", ascending=False).head(5)["hotel_id"].tolist()
    ),
    "top5",
    hotels["reg1_res"],
)
hotels["reg1_res"] = np.where(
    hotels["hotel_id"].isin(
        hotels.sort_values(by="e", ascending=False).tail(5)["hotel_id"].tolist()
    ),
    "bottom5",
    hotels["reg1_res"],
)

# %%
(
    ggplot(hotels, aes(x="distance", y="price"))
    + geom_point(aes(color="reg1_res"), alpha=0.6)
    + geom_point(
        hotels.loc[lambda x: x["reg1_res"] == "top5"], alpha=0.8, size=8, color="blue"
    )
    + geom_point(
        hotels.loc[lambda x: x["reg1_res"] == "bottom5"],
        alpha=0.8,
        size=10,
        color="red",
        fill="white",
    )
    + geom_smooth(method="lm", size=1, se=False, formula="y~x")
    + coord_cartesian(xlim=(0, 7), ylim=(0, 400))
    + expand_limits(x=0.01, y=0.01)
    + scale_color_discrete(guide=False)
    + scale_x_continuous(expand=(0.01, 0.01), limits=(0, 7), breaks=np.arange(0, 8, 1))
    + scale_y_continuous(
        expand=(0.01, 0.01), limits=(0, 400), breaks=np.arange(0, 401, 50)
    )
    + labs(x="Distance to city center (miles)", y="Price (US dollars)")
    + geom_segment(aes(x=2, y=25, xend=1.15, yend=50), arrow=arrow())
    + annotate("text", x=3, y=25, label="Most underpriced hotels", size=8)
    + theme_bw()
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## Log models

# %% [markdown]
# Take log price

# %%
hotels["lnprice"] = np.log(hotels["price"])

# %% [markdown]
# Correct distance2 measure: no closer than 0.05km

# %%
hotels["distance2"] = np.where(hotels["distance"] < 0.05, 0.05, hotels["distance"])

# %% [markdown]
# Take the log of distance2

# %%
hotels["lndistance"] = np.log(hotels["distance2"])

# %% [markdown]
# Describe price and ln price

# %%
hotels.filter(["price", "lnprice"]).describe(percentiles=[0.25, 0.5, 0.75, 0.95]).T
# Out:
#          count        mean        std        min        25%        50%  \
# price    207.0  109.975845  42.221381  50.000000  82.000000  100.00000
# lnprice  207.0    4.640219   0.336751   3.912023   4.406719    4.60517
#
#                 75%         95%         max
# price    129.500000  183.400000  383.000000
# lnprice    4.863673    5.211657    5.948035

# %% [markdown]
# ### Running multiple regressions:

# %% [markdown]
# 1. Level-level linear regression

# %%
reg1 = smf.ols("price ~ distance", data=hotels).fit()
print(reg1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     38.20
# Date:                Mon, 04 Nov 2024   Prob (F-statistic):           3.39e-09
# Time:                        12:45:01   Log-Likelihood:                -1050.3
# No. Observations:                 207   AIC:                             2105.
# Df Residuals:                     205   BIC:                             2111.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    132.0170      4.474     29.511      0.000     123.197     140.837
# distance     -14.4064      2.331     -6.181      0.000     -19.002      -9.811
# ==============================================================================
# Omnibus:                      141.994   Durbin-Watson:                   1.479
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1560.025
# Skew:                           2.497   Prob(JB):                         0.00
# Kurtosis:                      15.488   Cond. No.                         3.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
f1 = p1 + geom_smooth(
    aes(x="distance", y="price"), method="lm", color="blue", formula="y~x", se=True
)
f1
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# 2. Level-log linear regression

# %%
reg2 = smf.ols("price ~ lndistance", data=hotels).fit()
print(reg2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     79.58
# Date:                Mon, 04 Nov 2024   Prob (F-statistic):           2.61e-16
# Time:                        12:45:01   Log-Likelihood:                -1034.1
# No. Observations:                 207   AIC:                             2072.
# Df Residuals:                     205   BIC:                             2079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    112.4171      2.512     44.757      0.000     107.465     117.369
# lndistance   -24.7683      2.777     -8.921      0.000     -30.243     -19.294
# ==============================================================================
# Omnibus:                      175.079   Durbin-Watson:                   1.612
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3501.545
# Skew:                           3.084   Prob(JB):                         0.00
# Kurtosis:                      22.182   Cond. No.                         1.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
f2 = (
    ggplot(data=hotels)
    + geom_point(aes(x="lndistance", y="price"), color="red", size=2, alpha=0.5)
    + expand_limits(x=0.01, y=0.01)
    + scale_x_continuous(expand=(0.01, 0.01), limits=(-3, 2), breaks=range(-3, 3))
    + scale_y_continuous(
        expand=(0.01, 0.01), limits=(0, 400), breaks=np.arange(0, 401, 50)
    )
    + labs(x="ln(distance to city center, miles)", y="Price (US dollars)")
    + theme_bw()
    + geom_smooth(
        aes(x="lndistance", y="price"),
        method="lm",
        color="blue",
        formula="y~x",
        se=True,
    )
)
f2
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# 3. Log-level linear regression

# %%
reg3 = smf.ols("lnprice ~ distance", data=hotels).fit()
print(reg3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lnprice   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     52.90
# Date:                Mon, 04 Nov 2024   Prob (F-statistic):           7.30e-12
# Time:                        12:45:01   Log-Likelihood:                -44.160
# No. Observations:                 207   AIC:                             92.32
# Df Residuals:                     205   BIC:                             98.99
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.8411      0.035    139.720      0.000       4.773       4.909
# distance      -0.1313      0.018     -7.273      0.000      -0.167      -0.096
# ==============================================================================
# Omnibus:                       28.470   Durbin-Watson:                   1.564
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.450
# Skew:                           0.746   Prob(JB):                     4.97e-11
# Kurtosis:                       4.809   Cond. No.                         3.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
f3 = (
    ggplot(data=hotels)
    + geom_point(aes(x="distance", y="lnprice"), color="red", size=2, alpha=0.5)
    + expand_limits(x=0.01, y=0.01)
    + scale_x_continuous(expand=(0.01, 0.01), limits=(0, 7), breaks=range(0, 8))
    + scale_y_continuous(
        expand=(0.01, 0.01), limits=(3.5, 6), breaks=np.arange(3.5, 7, 0.5)
    )
    + labs(x="Distance to city center (miles)", y="ln(price, US dollars)")
    + theme_bw()
    + geom_smooth(
        aes(x="distance", y="lnprice"),
        method="lm",
        color="blue",
        formula="y~x",
        se=True,
    )
)
f3
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# 4. Log-log linear regression

# %%
reg4 = smf.ols("lnprice ~ lndistance", data=hotels).fit()
print(reg4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lnprice   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     102.6
# Date:                Mon, 04 Nov 2024   Prob (F-statistic):           8.18e-20
# Time:                        12:45:01   Log-Likelihood:                -25.911
# No. Observations:                 207   AIC:                             55.82
# Df Residuals:                     205   BIC:                             62.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.6615      0.019    241.926      0.000       4.623       4.699
# lndistance    -0.2158      0.021    -10.130      0.000      -0.258      -0.174
# ==============================================================================
# Omnibus:                       47.573   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.794
# Skew:                           0.976   Prob(JB):                     1.08e-28
# Kurtosis:                       6.335   Cond. No.                         1.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
f4 = (
    ggplot(data=hotels)
    + geom_point(aes(x="lndistance", y="lnprice"), color="red", size=2, alpha=0.5)
    + expand_limits(x=0.01, y=0.01)
    + scale_x_continuous(expand=(0.01, 0.01), limits=(-3, 2), breaks=range(-3, 3))
    + scale_y_continuous(
        expand=(0.01, 0.01), limits=(3.5, 6), breaks=np.arange(3.5, 7, 0.5)
    )
    + labs(x="ln(distance to city center, miles)", y="ln(price, US dollars)")
    + theme_bw()
    + geom_smooth(
        aes(x="lndistance", y="lnprice"),
        method="lm",
        color="blue",
        formula="y~x",
        se=True,
    )
)
f4
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# #### Checking and comparing all models:

# %%
table = Stargazer([reg1, reg2, reg3, reg4])
table.rename_covariates({"Intercept": "Constant"})
table.custom_columns(["Level-Level", "Level-Log", "Log-Level", "Log-Log"], [1, 1, 1, 1])
table
# Out:
# <table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Level-Level</td><td colspan="1">Level-Log</td><td colspan="1">Log-Level</td><td colspan="1">Log-Log</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Constant</td><td>132.017<sup>***</sup></td><td>112.417<sup>***</sup></td><td>4.841<sup>***</sup></td><td>4.661<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(4.474)</td><td>(2.512)</td><td>(0.035)</td><td>(0.019)</td></tr>
# <tr><td style="text-align:left">distance</td><td>-14.406<sup>***</sup></td><td></td><td>-0.131<sup>***</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(2.331)</td><td></td><td>(0.018)</td><td></td></tr>
# <tr><td style="text-align:left">lndistance</td><td></td><td>-24.768<sup>***</sup></td><td></td><td>-0.216<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(2.777)</td><td></td><td>(0.021)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>207</td><td>207</td><td>207</td><td>207</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.157</td><td>0.280</td><td>0.205</td><td>0.334</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.153</td><td>0.276</td><td>0.201</td><td>0.330</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>38.858 (df=205)</td><td>35.923 (df=205)</td><td>0.301 (df=205)</td><td>0.276 (df=205)</td></tr><tr><td style="text-align: left">F Statistic</td><td>38.199<sup>***</sup> (df=1; 205)</td><td>79.576<sup>***</sup> (df=1; 205)</td><td>52.895<sup>***</sup> (df=1; 205)</td><td>102.622<sup>***</sup> (df=1; 205)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
